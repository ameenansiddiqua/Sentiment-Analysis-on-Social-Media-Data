# %% [markdown]
# IMPORT LIBRARY

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# LOAD DATA

# %%
df=pd.read_csv("sentimentdataset.csv")

# %% [markdown]
# DATA EXPLORATION

# %%
df.shape
# Out:
# (732, 15)

# %%
df.describe().loc[['min', '50%', 'mean', 'max', 'std']].T.style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_b602d_row0_col0, #T_b602d_row1_col0, #T_b602d_row2_col0, #T_b602d_row3_col0, #T_b602d_row4_col4, #T_b602d_row5_col0, #T_b602d_row6_col0, #T_b602d_row7_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b602d_row0_col1, #T_b602d_row0_col2, #T_b602d_row1_col1, #T_b602d_row1_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_b602d_row0_col3, #T_b602d_row1_col3, #T_b602d_row2_col3, #T_b602d_row3_col3, #T_b602d_row4_col1, #T_b602d_row4_col2, #T_b602d_row4_col3, #T_b602d_row5_col3, #T_b602d_row6_col3, #T_b602d_row7_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b602d_row0_col4, #T_b602d_row1_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_b602d_row2_col1 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_b602d_row2_col2, #T_b602d_row3_col1, #T_b602d_row3_col2 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_b602d_row2_col4 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_b602d_row3_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_b602d_row4_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_b602d_row5_col1 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_b602d_row5_col2, #T_b602d_row6_col1 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_b602d_row5_col4 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_b602d_row6_col2 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_b602d_row6_col4 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_b602d_row7_col1 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_b602d_row7_col2 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_b602d_row7_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# </style>
# <table id="T_b602d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b602d_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_b602d_level0_col1" class="col_heading level0 col1" >50%</th>
#       <th id="T_b602d_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_b602d_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_b602d_level0_col4" class="col_heading level0 col4" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b602d_level0_row0" class="row_heading level0 row0" >Unnamed: 0.1</th>
#       <td id="T_b602d_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_b602d_row0_col1" class="data row0 col1" >366.500000</td>
#       <td id="T_b602d_row0_col2" class="data row0 col2" >366.464481</td>
#       <td id="T_b602d_row0_col3" class="data row0 col3" >732.000000</td>
#       <td id="T_b602d_row0_col4" class="data row0 col4" >211.513936</td>
#     </tr>
#     <tr>
#       <th id="T_b602d_level0_row1" class="row_heading level0 row1" >Unnamed: 0</th>
#       <td id="T_b602d_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_b602d_row1_col1" class="data row1 col1" >370.500000</td>
#       <td id="T_b602d_row1_col2" class="data row1 col2" >369.740437</td>
#       <td id="T_b602d_row1_col3" class="data row1 col3" >736.000000</td>
#       <td id="T_b602d_row1_col4" class="data row1 col4" >212.428936</td>
#     </tr>
#     <tr>
#       <th id="T_b602d_level0_row2" class="row_heading level0 row2" >Retweets</th>
#       <td id="T_b602d_row2_col0" class="data row2 col0" >5.000000</td>
#       <td id="T_b602d_row2_col1" class="data row2 col1" >22.000000</td>
#       <td id="T_b602d_row2_col2" class="data row2 col2" >21.508197</td>
#       <td id="T_b602d_row2_col3" class="data row2 col3" >40.000000</td>
#       <td id="T_b602d_row2_col4" class="data row2 col4" >7.061286</td>
#     </tr>
#     <tr>
#       <th id="T_b602d_level0_row3" class="row_heading level0 row3" >Likes</th>
#       <td id="T_b602d_row3_col0" class="data row3 col0" >10.000000</td>
#       <td id="T_b602d_row3_col1" class="data row3 col1" >43.000000</td>
#       <td id="T_b602d_row3_col2" class="data row3 col2" >42.901639</td>
#       <td id="T_b602d_row3_col3" class="data row3 col3" >80.000000</td>
#       <td id="T_b602d_row3_col4" class="data row3 col4" >14.089848</td>
#     </tr>
#     <tr>
#       <th id="T_b602d_level0_row4" class="row_heading level0 row4" >Year</th>
#       <td id="T_b602d_row4_col0" class="data row4 col0" >2010.000000</td>
#       <td id="T_b602d_row4_col1" class="data row4 col1" >2021.000000</td>
#       <td id="T_b602d_row4_col2" class="data row4 col2" >2020.471311</td>
#       <td id="T_b602d_row4_col3" class="data row4 col3" >2023.000000</td>
#       <td id="T_b602d_row4_col4" class="data row4 col4" >2.802285</td>
#     </tr>
#     <tr>
#       <th id="T_b602d_level0_row5" class="row_heading level0 row5" >Month</th>
#       <td id="T_b602d_row5_col0" class="data row5 col0" >1.000000</td>
#       <td id="T_b602d_row5_col1" class="data row5 col1" >6.000000</td>
#       <td id="T_b602d_row5_col2" class="data row5 col2" >6.122951</td>
#       <td id="T_b602d_row5_col3" class="data row5 col3" >12.000000</td>
#       <td id="T_b602d_row5_col4" class="data row5 col4" >3.411763</td>
#     </tr>
#     <tr>
#       <th id="T_b602d_level0_row6" class="row_heading level0 row6" >Day</th>
#       <td id="T_b602d_row6_col0" class="data row6 col0" >1.000000</td>
#       <td id="T_b602d_row6_col1" class="data row6 col1" >15.000000</td>
#       <td id="T_b602d_row6_col2" class="data row6 col2" >15.497268</td>
#       <td id="T_b602d_row6_col3" class="data row6 col3" >31.000000</td>
#       <td id="T_b602d_row6_col4" class="data row6 col4" >8.474553</td>
#     </tr>
#     <tr>
#       <th id="T_b602d_level0_row7" class="row_heading level0 row7" >Hour</th>
#       <td id="T_b602d_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_b602d_row7_col1" class="data row7 col1" >16.000000</td>
#       <td id="T_b602d_row7_col2" class="data row7 col2" >15.521858</td>
#       <td id="T_b602d_row7_col3" class="data row7 col3" >23.000000</td>
#       <td id="T_b602d_row7_col4" class="data row7 col4" >4.113414</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
df_columns=df.columns
for col in df.columns:
    print(col)
# Out:
# Unnamed: 0.1
# Unnamed: 0
# Text
# Sentiment
# Timestamp
# User
# Platform
# Hashtags
# Retweets
# Likes
# Country
# Year
# Month
# Day
# Hour

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# 2   #Fitness #Workout                              20.0   40.0   USA
# 3   #Travel #Adventure                              8.0   15.0     UK
# 4   #Cooking #Food                                 12.0   25.0    Australia
#
#    Year  Month  Day  Hour
# 0  2023      1   15    12
# 1  2023      1   15     8
# 2  2023      1   15    15
# 3  2023      1   15    18
# 4  2023      1   15    19

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# VISUALIZATION ON DATA

# %%
sns.pairplot(df, hue = 'Platform',corner=True )

# %%
sns.displot(df.Likes)

# %%
sns.displot(df.Platform ,fill=True)

# %%
sns.countplot(x = 'Platform' , data = df)
plt.show()

# %%
sns.histplot(df['Likes'],bins=20,color='Blue',edgecolor='Red',kde=True)
plt.xlabel("likes")
plt.ylabel("platform")
plt.title("likes_of_platform")
# Out:
# Text(0.5, 1.0, 'likes_of_platform')

# %%
sns.regplot(data = df , x ='Hour' , y ='Likes')
# Out:
# <Axes: xlabel='Hour', ylabel='Likes'>

# %%
sns.scatterplot(data = df , x ='Hour' , y ='Likes')
# Out:
# <Axes: xlabel='Hour', ylabel='Likes'>

# %%
plot = sns.PairGrid(df)
plot.map(plt.plot)
plt.show()

# %%
df['Sentiment'].value_counts().nlargest(10).plot(kind='bar')
plt.title('Top 10 Sentiments based on Text')
plt.xlabel('Sentiment')
plt.ylabel('text')
plt.show()

# %%
df['Platform'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Percentages of Platforms')
plt.legend()
plt.show()

# %%
df['Country'].value_counts().nlargest(10).plot(kind='bar')
plt.title('Based on Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %%
H_retweet= df.groupby('Hashtags')['Retweets'].max().value_counts().nlargest(10).sort_values(ascending=True).plot(kind='bar')
